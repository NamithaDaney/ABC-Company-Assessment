# %% [markdown]
# <a href="https://colab.research.google.com/github/NamithaDaney/ABC-Company-Assessment/blob/main/Module_2_Python_Assessment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_excel('/content/drive/MyDrive/ENTRI Folder/ABC Company.xlsx')
df.head()
# Out:
#             Name            Team  Number Position  Age               Height  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1    Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2   John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3    R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
#
#    Weight            College     Salary
# 0     180              Texas  7730337.0
# 1     235          Marquette  6796117.0
# 2     205  Boston University        NaN
# 3     185      Georgia State  1148640.0
# 4     231                NaN  5000000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  221.543668  4.833970e+06
# std     15.966837    4.400128   26.343200  5.226620e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df.shape
# Out:
# (458, 9)

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df["College"] = df["College"].fillna(df["College"].mode()[0])#fill the null values with mode of column College
df.isna().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College      0
# Salary      11
# dtype: int64

# %%
df["Salary"] = df["Salary"].fillna(df["Salary"].mean())
df.isna().sum()
df["Salary"]
# Out:
# 0      7.730337e+06
# 1      6.796117e+06
# 2      4.833970e+06
# 3      1.148640e+06
# 4      5.000000e+06
#            ...
# 453    2.433333e+06
# 454    9.000000e+05
# 455    2.900000e+06
# 456    9.472760e+05
# 457    9.472760e+05
# Name: Salary, Length: 458, dtype: float64

# %% [markdown]
# 1. Preprocessing:
# ● Correct the data in the "height" column by replacing it with random
# numbers between 150 and 180. Ensure data consistency and integrity
# before proceeding with analysis. (1 mark)

# %%
import random
df["Height"] = df['Height'].apply(lambda x: random.randint(150, 180)) #replacing it with random numbers between 150 and 180
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     169     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     156     235
# 2   John Holland  Boston Celtics      30       SG   27     180     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     177     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     152     231
#
#              College        Salary
# 0              Texas  7.730337e+06
# 1          Marquette  6.796117e+06
# 2  Boston University  4.833970e+06
# 3      Georgia State  1.148640e+06
# 4           Kentucky  5.000000e+06

# %%
df["Height"].dtype
# Out:
# dtype('int64')

# %% [markdown]
# **Analysis Tasks:**
#
#
# 1.   Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees. (2 marks)
# 2.   Segregate employees based on their positions within the company. (2marks)
# 3. Identify the predominant age group among employees. (2marks)
# 4. Discover which team and position have the highest salary expenditure. (2marks)
# 5. Investigate if there's any correlation between age and salary, andrepresent it visually. (2 marks)

# %%
team_Count = df["Team"].value_counts()
team_Count
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# Milwaukee Bucks           16
# New York Knicks           16
# Boston Celtics            15
# Los Angeles Clippers      15
# Los Angeles Lakers        15
# Phoenix Suns              15
# Sacramento Kings          15
# Brooklyn Nets             15
# Philadelphia 76ers        15
# Toronto Raptors           15
# Golden State Warriors     15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Houston Rockets           15
# San Antonio Spurs         15
# Atlanta Hawks             15
# Dallas Mavericks          15
# Charlotte Hornets         15
# Miami Heat                15
# Denver Nuggets            15
# Washington Wizards        15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
df_percentage = team_Count / team_Count.sum() * 100
df_percentage #the percentage of employees in each team
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# Milwaukee Bucks           3.493450
# New York Knicks           3.493450
# Boston Celtics            3.275109
# Los Angeles Clippers      3.275109
# Los Angeles Lakers        3.275109
# Phoenix Suns              3.275109
# Sacramento Kings          3.275109
# Brooklyn Nets             3.275109
# Philadelphia 76ers        3.275109
# Toronto Raptors           3.275109
# Golden State Warriors     3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Houston Rockets           3.275109
# San Antonio Spurs         3.275109
# Atlanta Hawks             3.275109
# Dallas Mavericks          3.275109
# Charlotte Hornets         3.275109
# Miami Heat                3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# ...

# %%
df['Team'].nunique()

df["Position"].nunique()
# Out:
# 5

# %% [markdown]
# **Segregate employees based on their positions within the company. (2marks)**

# %%
#Segregate employees based on their positions within the company.
for position,info in df.groupby('Position')[['Name', 'Team']]:
  print(f"\nPosition: {position}")
  print(info)
# Out:
# Position: C
#                 Name                    Team
# 7       Kelly Olynyk          Boston Celtics
# 10   Jared Sullinger          Boston Celtics
# 14      Tyler Zeller          Boston Celtics
# 23       Brook Lopez           Brooklyn Nets
# 27        Henry Sims           Brooklyn Nets
# ..               ...                     ...
# 439    Mason Plumlee  Portland Trail Blazers
# 447      Rudy Gobert               Utah Jazz
# 455     Tibor Pleiss               Utah Jazz
# 456      Jeff Withey               Utah Jazz
# 457         Priyanka               Utah Jazz
#
# [79 rows x 2 columns]
#
# Position: PF
#                  Name                    Team
# 4       Jonas Jerebko          Boston Celtics
# 5        Amir Johnson          Boston Celtics
# 6       Jordan Mickey          Boston Celtics
# 24   Chris McCullough           Brooklyn Nets
# 25        Willie Reed           Brooklyn Nets
# ..                ...                     ...
# ...

# %% [markdown]
# **Identify the predominant age group among employees. (2marks)**

# %%
#Identify the predominant age group among employees.

age_group = df.groupby('Age').size()
age_group
# Out:
# Age
# 19     2
# 20    19
# 21    19
# 22    26
# 23    41
# 24    47
# 25    46
# 26    36
# 27    41
# 28    31
# 29    28
# 30    31
# 31    22
# 32    13
# 33    14
# 34    10
# 35     9
# 36    10
# 37     4
# 38     4
# 39     2
# 40     3
# dtype: int64

# %%
dict_age = age_group.to_dict()
dict_age
# Out:
# {19: 2,
#  20: 19,
#  21: 19,
#  22: 26,
#  23: 41,
#  24: 47,
#  25: 46,
#  26: 36,
#  27: 41,
#  28: 31,
#  29: 28,
#  30: 31,
#  31: 22,
#  32: 13,
#  33: 14,
#  34: 10,
#  35: 9,
#  36: 10,
#  37: 4,
#  38: 4,
#  39: 2,
#  40: 3}

# %%
total1 = age_group.iloc[1:11].sum()

print(f"Age group of 20-30 has total employees of {total1}")
#print(age_group.iloc[1:12])
total2 = age_group.iloc[11:21].sum()
print(f"Age group of 30-40 has total employees of {total2}")
#print(age_group.iloc[11:22])
if total1 > total2:
  print("Age group of 20-30 has more employees")
elif total1 == total2:
  print("Age group of 20-30 and 30-40 has equal employees")
else:
  print("Age group of 30-40 has more employees")
# Out:
# Age group of 20-30 has total employees of 334
# Age group of 30-40 has total employees of 119
# Age group of 20-30 has more employees

# %% [markdown]
# **Discover which team and position have the highest salary expenditure.**

# %%
highest_Salary = df.groupby(["Team",'Position'])['Salary'].sum()
high_Salary = highest_Salary.max()
position = highest_Salary.idxmax()
print(f"The team and position have the highest salary expenditure is {position} with salary of {high_Salary}")
# Out:
# The team and position have the highest salary expenditure is ('Los Angeles Lakers', 'SF') with salary of 31866445.0

# %% [markdown]
# **Investigate if there's any correlation between age and salary, and represent it visually.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(x=df['Age'], y=df['Salary'])
plt.title('Age vs Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# From this graph it is evident that is no specific correlation between age and salary. Employees accross all age groups appers to have almost similar minimum salary level.

# %% [markdown]
# Graphical Representation:
# 1.   For each of the five analysis tasks above, create appropriate visualizations to present your findings effectively. (5x2 = 10 marks)
# 2.   Data Story: Provide insights gained from the analysis, highlighting key
# trends, patterns, and correlations within the dataset. (3 marks)
# 3. Timely Submission: Ensure timely submission of your project to earn an
# additional mark. (1 mark)

# %%
#Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees.
from matplotlib import figure
plt.figure(figsize=(20,10))
plt.pie(df['Team'].value_counts(), labels=df['Team'].value_counts().index, autopct='%1.1f%%')
plt.title('Distribution of employees across each team')
plt.show()

# %% [markdown]
# The distribution of employees across each team almost similar.The percentage distribution of most team is close to 3.3 percent. The team 'New Orleans Pelicans' has the highest percentage of employees(4.1per cent.)

# %%
#Segregate employees based on their positions within the company
plt.figure(figsize=(10,5))
sns.countplot(x='Position', data=df)
plt.title('Distribution of Employees by Position')
plt.xlabel('Position')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# The position 'SG' has highest number of employees(110). The position 'C' has comparatively lower number of employees(80).

# %%
#Identify the predominant age group among employees
plt.figure(figsize=(10,5))
sns.countplot(x='Age', data=df)
plt.title('Distribution of Employees by Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Employees aged 24 are dominant in the company. The age group of 20-30 is highest among all other age groups.

# %%
#Discover which team and position have the highest salary expenditure.
plt.figure(figsize=(100,40))
highest_Salary.plot(kind='bar')
plt.title('Team and Position with Highest Salary Expenditure',fontsize=60, fontweight='bold')
plt.xlabel('Team and Position')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# 'Los Angeles Lakers', 'SF' have the highest salary expenditure of 31866445.0.'Orlando Magic', 'SF' has minimum salary expenditure of 845059.0

# %%
sns.scatterplot(x=df['Age'], y=df['Salary'])
plt.title('Age vs Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# From this graph, it is evident that there is no specific correlation between age and salary. Employees across all age groups appear to have almost similar minimum salary levels.
